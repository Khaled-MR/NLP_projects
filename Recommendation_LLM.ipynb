# %%
# !pip install faiss-cpu requests
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0.post1-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: requests in c:\users\khaled sayed\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: numpy<2.0,>=1.0 in c:\users\khaled sayed\anaconda3\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\khaled sayed\anaconda3\lib\site-packages (from faiss-cpu) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khaled sayed\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khaled sayed\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khaled sayed\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khaled sayed\anaconda3\lib\site-packages (from requests) (2024.6.2)
# Downloading faiss_cpu-1.8.0.post1-cp312-cp312-win_amd64.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.6 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.6 MB 3.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/14.6 MB 3.9 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/14.6 MB 3.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.7/14.6 MB 3.9 MB/s eta 0:00:03
#    ------------ --------------------------- 4.5/14.6 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 5.2/14.6 MB 3.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 6.3/14.6 MB 3.9 MB/s eta 0:00:03
#    ------------------- -------------------- 7.1/14.6 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 7.1/14.6 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 8.9/14.6 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 9.2/14.6 MB 3.7 MB/s eta 0:00:02
#    --------------------------- ------------ 10.0/14.6 MB 3.5 MB/s eta 0:00:02
#    ------------------------------- -------- 11.5/14.6 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 12.3/14.6 MB 3.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.8/14.6 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 3.0 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0.post1

# %%
import pandas as pd

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
def create_textual_representation(row):
    textual_representation =f"""
    Type: {row['type']},
    Title: {row['title']},
    Director: {row['director']},
    Cast: {row['cast']},
    Release Year: {row['release_year']},
    Listed In: {row['listed_in']},
    Description: {row['description']}
    """
    return textual_representation

# %%
df['textual_representation'] = df.apply(create_textual_representation, axis=1)

# %%
print(df['textual_representation'].values[0])
# Out:
#     Type: Movie,
#     Title: Dick Johnson Is Dead,
#     Director: Kirsten Johnson,
#     Cast: nan,
#     Release Year: 2020,
#     Listed In: Documentaries,
#     Description: As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.

# %%
import faiss
import requests
import numpy as np

dim = 4096
index = faiss.IndexFlatL2(dim)

X = np.zeros((len(df['textual_representation']), dim),dtype='float32')

# %%
X[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
for i , representation in enumerate(df['textual_representation']):
    if i % 100:
       print('processed',str(i),'instances')
    res = requests.post('http://localhost:11434/api/embeddings',
                      json={
                          'model':'llama2',
                          'prompt':representation
                      }
                      )
    embedding = res.json()['embedding']
    X[i] = np.array(embedding)


index.add(np.array([embedding]))
# Out:
# processed 1 instances
# processed 2 instances
# processed 3 instances
# processed 4 instances
# processed 5 instances
# processed 6 instances
# processed 7 instances
# processed 8 instances
# processed 9 instances
# processed 10 instances
# processed 11 instances
# processed 12 instances
# processed 13 instances
# processed 14 instances
# processed 15 instances
# processed 16 instances
# processed 17 instances
# processed 18 instances
# processed 19 instances
# processed 20 instances
# processed 21 instances
# processed 22 instances
# processed 23 instances
# processed 24 instances
# processed 25 instances
# processed 26 instances
# processed 27 instances
# processed 28 instances
# processed 29 instances
# processed 30 instances
# processed 31 instances
# processed 32 instances
# processed 33 instances
# processed 34 instances
# processed 35 instances
# processed 36 instances
# processed 37 instances
# processed 38 instances
# processed 39 instances
# processed 40 instances
# processed 41 instances
# processed 42 instances
# processed 43 instances
# processed 44 instances
# processed 45 instances
# processed 46 instances
# processed 47 instances
# processed 48 instances
# processed 49 instances
# processed 50 instances
# processed 51 instances
# processed 52 instances
# processed 53 instances
# processed 54 instances
# processed 55 instances
# processed 56 instances
# processed 57 instances
# processed 58 instances
# processed 59 instances
# processed 60 instances
# processed 61 instances
# processed 62 instances
# processed 63 instances
# processed 64 instances
# processed 65 instances
# processed 66 instances
# processed 67 instances
# processed 68 instances
# processed 69 instances
# processed 70 instances
# processed 71 instances
# processed 72 instances
# processed 73 instances
# processed 74 instances
# processed 75 instances
# processed 76 instances
# processed 77 instances
# processed 78 instances
# processed 79 instances
# processed 80 instances
# processed 81 instances
# processed 82 instances
# processed 83 instances
# processed 84 instances
# processed 85 instances
# processed 86 instances
# processed 87 instances
# processed 88 instances
# processed 89 instances
# processed 90 instances
# processed 91 instances
# processed 92 instances
# processed 93 instances
# processed 94 instances
# processed 95 instances
# processed 96 instances
# processed 97 instances
# processed 98 instances
# processed 99 instances
# processed 101 instances
# processed 102 instances
# processed 103 instances
# processed 104 instances
# processed 105 instances
# processed 106 instances
# processed 107 instances
# processed 108 instances
# processed 109 instances
# processed 110 instances
# processed 111 instances
# processed 112 instances
# processed 113 instances
# processed 114 instances
# processed 115 instances
# processed 116 instances
# processed 117 instances
# processed 118 instances
# processed 119 instances
# processed 120 instances
# processed 121 instances
# processed 122 instances
# processed 123 instances
# processed 124 instances
# processed 125 instances
# processed 126 instances
# processed 127 instances
# processed 128 instances
# processed 129 instances
# processed 130 instances
# processed 131 instances
# processed 132 instances
# processed 133 instances
# processed 134 instances
# processed 135 instances
# processed 136 instances
# processed 137 instances
# processed 138 instances
# processed 139 instances
# processed 140 instances
# processed 141 instances
# processed 142 instances
# processed 143 instances
# processed 144 instances
# processed 145 instances
# processed 146 instances
# processed 147 instances
# processed 148 instances
# processed 149 instances
# processed 150 instances
# processed 151 instances
# processed 152 instances
# processed 153 instances
# processed 154 instances
# processed 155 instances
# processed 156 instances
# processed 157 instances
# processed 158 instances
# processed 159 instances
# processed 160 instances
# processed 161 instances
# processed 162 instances
# processed 163 instances
# processed 164 instances
# processed 165 instances
# processed 166 instances
# processed 167 instances
# processed 168 instances
# processed 169 instances
# processed 170 instances
# processed 171 instances
# processed 172 instances
# processed 173 instances
# processed 174 instances
# processed 175 instances
# processed 176 instances
# processed 177 instances
# processed 178 instances
# processed 179 instances
# processed 180 instances
# processed 181 instances
# processed 182 instances
# processed 183 instances
# processed 184 instances
# processed 185 instances
# processed 186 instances
# processed 187 instances
# processed 188 instances
# processed 189 instances
# processed 190 instances
# processed 191 instances
# processed 192 instances
# processed 193 instances
# processed 194 instances
# processed 195 instances
# processed 196 instances
# processed 197 instances
# processed 198 instances
# processed 199 instances
# processed 201 instances
# processed 202 instances
# processed 203 instances
# processed 204 instances
# processed 205 instances
# processed 206 instances
# processed 207 instances
# processed 208 instances
# processed 209 instances
# processed 210 instances
# processed 211 instances
# processed 212 instances
# processed 213 instances
# processed 214 instances
# processed 215 instances
# processed 216 instances
# processed 217 instances
# processed 218 instances
# processed 219 instances
# processed 220 instances
# processed 221 instances
# processed 222 instances
# processed 223 instances
# processed 224 instances
# processed 225 instances
# processed 226 instances
# processed 227 instances
# processed 228 instances
# processed 229 instances
# processed 230 instances
# processed 231 instances
# processed 232 instances
# processed 233 instances
# processed 234 instances
# processed 235 instances
# processed 236 instances
# processed 237 instances
# processed 238 instances
# processed 239 instances
# processed 240 instances
# processed 241 instances
# processed 242 instances
# processed 243 instances
# processed 244 instances
# processed 245 instances
# processed 246 instances
# processed 247 instances
# processed 248 instances
# processed 249 instances
# processed 250 instances
# processed 251 instances
# processed 252 instances
# processed 253 instances
# processed 254 instances
# processed 255 instances
# processed 256 instances
# processed 257 instances
# processed 258 instances
# processed 259 instances
# processed 260 instances
# processed 261 instances
# processed 262 instances
# processed 263 instances
# processed 264 instances
# processed 265 instances
# processed 266 instances
# processed 267 instances
# processed 268 instances
# processed 269 instances
# processed 270 instances
# processed 271 instances
# processed 272 instances
# processed 273 instances
# processed 274 instances
# processed 275 instances
# processed 276 instances
# processed 277 instances
# processed 278 instances
# processed 279 instances
# processed 280 instances
# processed 281 instances
# processed 282 instances
# processed 283 instances
# processed 284 instances
# processed 285 instances
# processed 286 instances
# processed 287 instances
# processed 288 instances
# processed 289 instances
# processed 290 instances
# processed 291 instances
# processed 292 instances
# processed 293 instances
# processed 294 instances
# processed 295 instances
# processed 296 instances
# processed 297 instances
# processed 298 instances
# processed 299 instances
# processed 301 instances
# processed 302 instances
# processed 303 instances
# processed 304 instances
# processed 305 instances
# processed 306 instances
# processed 307 instances
# processed 308 instances
# processed 309 instances
# processed 310 instances
# processed 311 instances
# processed 312 instances
# processed 313 instances
# processed 314 instances
# processed 315 instances
# processed 316 instances
# processed 317 instances
# processed 318 instances
# processed 319 instances
# processed 320 instances
# processed 321 instances
# processed 322 instances
# processed 323 instances
# processed 324 instances
# processed 325 instances
# processed 326 instances
# processed 327 instances
# processed 328 instances
# processed 329 instances
# processed 330 instances
# processed 331 instances
# processed 332 instances
# processed 333 instances
# processed 334 instances
# processed 335 instances
# processed 336 instances
# processed 337 instances
# processed 338 instances
# processed 339 instances
# processed 340 instances
# processed 341 instances
# processed 342 instances
# processed 343 instances
# processed 344 instances
# processed 345 instances
# processed 346 instances
# processed 347 instances
# processed 348 instances
# processed 349 instances
# processed 350 instances
# processed 351 instances
# processed 352 instances
# processed 353 instances
# processed 354 instances
# processed 355 instances
# processed 356 instances
# processed 357 instances
# processed 358 instances
# processed 359 instances
# processed 360 instances
# processed 361 instances
# processed 362 instances
# processed 363 instances
# processed 364 instances
# processed 365 instances
# processed 366 instances
# processed 367 instances
# processed 368 instances
# processed 369 instances
# processed 370 instances
# processed 371 instances
# processed 372 instances
# processed 373 instances
# processed 374 instances
# processed 375 instances
# processed 376 instances
# processed 377 instances
# processed 378 instances
# processed 379 instances
# processed 380 instances
# processed 381 instances
# processed 382 instances
# processed 383 instances
# processed 384 instances
# processed 385 instances
# processed 386 instances
# processed 387 instances
# processed 388 instances
# processed 389 instances
# processed 390 instances
# processed 391 instances
# processed 392 instances
# processed 393 instances
# processed 394 instances
# processed 395 instances
# processed 396 instances
# processed 397 instances
# processed 398 instances
# processed 399 instances
# processed 401 instances
# processed 402 instances
# processed 403 instances
# processed 404 instances
# processed 405 instances
# processed 406 instances
# processed 407 instances
# processed 408 instances
# processed 409 instances
# processed 410 instances
# processed 411 instances
# processed 412 instances
# processed 413 instances
# processed 414 instances
# processed 415 instances
# processed 416 instances
# processed 417 instances
# processed 418 instances
# processed 419 instances
# processed 420 instances
# processed 421 instances
# processed 422 instances
# processed 423 instances
# processed 424 instances
# processed 425 instances
# processed 426 instances
# processed 427 instances
# processed 428 instances
# processed 429 instances
# processed 430 instances
# processed 431 instances
# processed 432 instances
# processed 433 instances
# processed 434 instances
# processed 435 instances
# processed 436 instances
# processed 437 instances
# processed 438 instances
# processed 439 instances
# processed 440 instances
# processed 441 instances
# processed 442 instances
# processed 443 instances
# processed 444 instances
# processed 445 instances
# processed 446 instances
# processed 447 instances
# processed 448 instances
# processed 449 instances
# processed 450 instances
# processed 451 instances
# processed 452 instances
# processed 453 instances
# processed 454 instances
# processed 455 instances
# processed 456 instances
# processed 457 instances
# processed 458 instances
# processed 459 instances
# processed 460 instances
# processed 461 instances
# processed 462 instances
# processed 463 instances
# processed 464 instances
# processed 465 instances
# processed 466 instances
# processed 467 instances
# processed 468 instances
# processed 469 instances
# processed 470 instances
# processed 471 instances
# processed 472 instances
# processed 473 instances
# processed 474 instances
# processed 475 instances
# processed 476 instances
# processed 477 instances
# processed 478 instances
# processed 479 instances
# processed 480 instances
# processed 481 instances
# processed 482 instances
# processed 483 instances
# processed 484 instances
# processed 485 instances
# processed 486 instances
# processed 487 instances
# processed 488 instances
# processed 489 instances
# processed 490 instances
# processed 491 instances
# processed 492 instances
# processed 493 instances
# processed 494 instances
# processed 495 instances
# processed 496 instances
# processed 497 instances
# processed 498 instances
# processed 499 instances
# processed 501 instances
# processed 502 instances
# processed 503 instances
# processed 504 instances
# processed 505 instances
# processed 506 instances
# processed 507 instances
# processed 508 instances
# processed 509 instances
# processed 510 instances
# processed 511 instances
# processed 512 instances
# processed 513 instances
# processed 514 instances
# processed 515 instances
# processed 516 instances
# processed 517 instances
# processed 518 instances
# processed 519 instances
# processed 520 instances
# processed 521 instances
# processed 522 instances
# processed 523 instances
# processed 524 instances
# processed 525 instances
# processed 526 instances
# processed 527 instances
# processed 528 instances
# processed 529 instances
# processed 530 instances
# processed 531 instances
# processed 532 instances
# processed 533 instances
# processed 534 instances
# processed 535 instances
# processed 536 instances
# processed 537 instances
# processed 538 instances
# processed 539 instances
# processed 540 instances
# processed 541 instances
# processed 542 instances
# processed 543 instances
# processed 544 instances
# processed 545 instances
# processed 546 instances
# processed 547 instances
# processed 548 instances
# processed 549 instances
# processed 550 instances
# processed 551 instances
# processed 552 instances
# processed 553 instances
# processed 554 instances
# processed 555 instances
# processed 556 instances
# processed 557 instances
# processed 558 instances
# processed 559 instances
# processed 560 instances
# processed 561 instances
# processed 562 instances
# processed 563 instances
# processed 564 instances
# processed 565 instances
# processed 566 instances
# processed 567 instances
# processed 568 instances
# processed 569 instances
# processed 570 instances
# processed 571 instances
# processed 572 instances
# processed 573 instances
# processed 574 instances
# processed 575 instances
# processed 576 instances
# processed 577 instances
# processed 578 instances
# processed 579 instances
# processed 580 instances
# processed 581 instances
# processed 582 instances
# processed 583 instances
# processed 584 instances
# processed 585 instances
# processed 586 instances
# processed 587 instances
# processed 588 instances
# processed 589 instances
# processed 590 instances
# processed 591 instances
# processed 592 instances
# processed 593 instances
# processed 594 instances
# processed 595 instances
# processed 596 instances
# processed 597 instances
# processed 598 instances
# processed 599 instances
# processed 601 instances
# processed 602 instances
# processed 603 instances
# processed 604 instances
# processed 605 instances
# processed 606 instances
# processed 607 instances
# processed 608 instances
# processed 609 instances
# processed 610 instances
# processed 611 instances
# processed 612 instances
# processed 613 instances
# processed 614 instances
# processed 615 instances
# processed 616 instances
# processed 617 instances
# processed 618 instances
# processed 619 instances
# processed 620 instances
# processed 621 instances
# processed 622 instances
# processed 623 instances
# processed 624 instances
# processed 625 instances
# processed 626 instances
# processed 627 instances
# processed 628 instances
# processed 629 instances
# processed 630 instances
# processed 631 instances
# processed 632 instances
# processed 633 instances
# processed 634 instances
# processed 635 instances
# processed 636 instances
# processed 637 instances
# processed 638 instances
# processed 639 instances
# processed 640 instances
# processed 641 instances
# processed 642 instances
# processed 643 instances
# processed 644 instances
# processed 645 instances
# processed 646 instances
# processed 647 instances
# processed 648 instances
# processed 649 instances
# processed 650 instances
# processed 651 instances
# processed 652 instances
# processed 653 instances
# processed 654 instances
# processed 655 instances
# processed 656 instances
# processed 657 instances
# processed 658 instances
# processed 659 instances
# processed 660 instances
# processed 661 instances
# processed 662 instances
# processed 663 instances
# processed 664 instances
# processed 665 instances
# processed 666 instances
# processed 667 instances
# processed 668 instances
# processed 669 instances
# processed 670 instances
# processed 671 instances
# processed 672 instances
# processed 673 instances
# processed 674 instances
# processed 675 instances
# processed 676 instances
# processed 677 instances
# processed 678 instances
# processed 679 instances
# processed 680 instances
# processed 681 instances
# processed 682 instances
# processed 683 instances
# processed 684 instances
# processed 685 instances
# processed 686 instances
# processed 687 instances
# processed 688 instances
# processed 689 instances
# processed 690 instances
# processed 691 instances
# processed 692 instances
# processed 693 instances
# processed 694 instances
# processed 695 instances
# processed 696 instances
# processed 697 instances
# processed 698 instances
# processed 699 instances
# processed 701 instances
# processed 702 instances
# processed 703 instances
# processed 704 instances
# processed 705 instances
# processed 706 instances
# processed 707 instances
# processed 708 instances
# processed 709 instances
# processed 710 instances
# processed 711 instances
# processed 712 instances
# processed 713 instances
# processed 714 instances
# processed 715 instances
# processed 716 instances
# processed 717 instances
# processed 718 instances
# processed 719 instances
# processed 720 instances
# processed 721 instances
# processed 722 instances
# processed 723 instances
# processed 724 instances
# processed 725 instances
# processed 726 instances
# processed 727 instances
# processed 728 instances
# processed 729 instances
# processed 730 instances
# processed 731 instances
# processed 732 instances
# processed 733 instances
# processed 734 instances
# processed 735 instances
# processed 736 instances
# processed 737 instances
# processed 738 instances
# processed 739 instances
# processed 740 instances
# processed 741 instances
# processed 742 instances
# processed 743 instances
# processed 744 instances
# processed 745 instances
# processed 746 instances
# processed 747 instances
# processed 748 instances
# processed 749 instances
# processed 750 instances
# processed 751 instances
# processed 752 instances
# processed 753 instances
# processed 754 instances
# processed 755 instances
# processed 756 instances
# processed 757 instances
# processed 758 instances
# processed 759 instances
# processed 760 instances
# processed 761 instances
# processed 762 instances
# processed 763 instances
# processed 764 instances
# processed 765 instances
# processed 766 instances
# processed 767 instances
# processed 768 instances
# processed 769 instances
# processed 770 instances
# processed 771 instances
# processed 772 instances
# processed 773 instances
# processed 774 instances
# processed 775 instances
# processed 776 instances
# processed 777 instances
# processed 778 instances
# processed 779 instances
# processed 780 instances
# processed 781 instances
# processed 782 instances
# processed 783 instances
# processed 784 instances
# processed 785 instances
# processed 786 instances
# processed 787 instances
# processed 788 instances
# processed 789 instances
# processed 790 instances
# processed 791 instances
# processed 792 instances
# processed 793 instances
# processed 794 instances
# processed 795 instances
# processed 796 instances
# processed 797 instances
# processed 798 instances
# processed 799 instances
# processed 801 instances
# processed 802 instances
# processed 803 instances
# processed 804 instances
# processed 805 instances
# processed 806 instances
# processed 807 instances
# processed 808 instances
# processed 809 instances
# processed 810 instances
# processed 811 instances
# processed 812 instances
# processed 813 instances
# processed 814 instances
# processed 815 instances
# processed 816 instances
# processed 817 instances
# processed 818 instances
# processed 819 instances
# processed 820 instances
# processed 821 instances
# processed 822 instances
# processed 823 instances
# processed 824 instances
# processed 825 instances
# processed 826 instances
# processed 827 instances
# processed 828 instances
# processed 829 instances
# processed 830 instances
# processed 831 instances
# processed 832 instances
# processed 833 instances
# processed 834 instances
# processed 835 instances
# processed 836 instances
# processed 837 instances
# processed 838 instances
# processed 839 instances
# processed 840 instances
# processed 841 instances
# processed 842 instances
# processed 843 instances
# processed 844 instances
# processed 845 instances
# processed 846 instances
# processed 847 instances
# processed 848 instances
# processed 849 instances
# processed 850 instances
# processed 851 instances
# processed 852 instances
# processed 853 instances
# processed 854 instances
# processed 855 instances
# processed 856 instances
# processed 857 instances
# processed 858 instances
# processed 859 instances
# processed 860 instances
# processed 861 instances
# processed 862 instances
# processed 863 instances
# processed 864 instances
# processed 865 instances
# processed 866 instances
# processed 867 instances
# processed 868 instances
# processed 869 instances
# processed 870 instances
# processed 871 instances
# processed 872 instances
# processed 873 instances
# processed 874 instances
# processed 875 instances
# processed 876 instances
# processed 877 instances
# processed 878 instances
# processed 879 instances
# processed 880 instances
# processed 881 instances
# processed 882 instances
# processed 883 instances
# processed 884 instances
# processed 885 instances
# processed 886 instances
# processed 887 instances
# processed 888 instances
# processed 889 instances
# processed 890 instances
# processed 891 instances
# processed 892 instances
# processed 893 instances
# processed 894 instances
# processed 895 instances
# processed 896 instances
# processed 897 instances
# processed 898 instances
# processed 899 instances
# processed 901 instances
# processed 902 instances
# processed 903 instances
# processed 904 instances
# processed 905 instances
# processed 906 instances
# processed 907 instances
# processed 908 instances
# processed 909 instances
# processed 910 instances
# processed 911 instances
# processed 912 instances
# processed 913 instances
# processed 914 instances
# processed 915 instances
# processed 916 instances
# processed 917 instances
# processed 918 instances
# processed 919 instances
# processed 920 instances
# processed 921 instances
# processed 922 instances
# processed 923 instances
# processed 924 instances
# processed 925 instances
# processed 926 instances
# processed 927 instances
# processed 928 instances
# processed 929 instances
# processed 930 instances
# processed 931 instances
# processed 932 instances
# processed 933 instances
# processed 934 instances
# processed 935 instances
# processed 936 instances
# processed 937 instances
# processed 938 instances
# processed 939 instances
# processed 940 instances
# processed 941 instances
# processed 942 instances
# processed 943 instances
# processed 944 instances
# processed 945 instances
# processed 946 instances
# processed 947 instances
# processed 948 instances
# processed 949 instances
# processed 950 instances
# processed 951 instances
# processed 952 instances
# processed 953 instances
# processed 954 instances
# processed 955 instances
# processed 956 instances
# processed 957 instances
# processed 958 instances
# processed 959 instances
# processed 960 instances
# processed 961 instances
# processed 962 instances
# processed 963 instances
# processed 964 instances
# processed 965 instances
# processed 966 instances
# processed 967 instances
# processed 968 instances
# processed 969 instances
# processed 970 instances
# processed 971 instances
# processed 972 instances
# processed 973 instances
# processed 974 instances
# processed 975 instances
# processed 976 instances
# processed 977 instances
# processed 978 instances
# processed 979 instances
# processed 980 instances
# processed 981 instances
# processed 982 instances
# processed 983 instances
# processed 984 instances
# processed 985 instances
# processed 986 instances
# processed 987 instances
# processed 988 instances
# processed 989 instances
# processed 990 instances
# processed 991 instances
# processed 992 instances
# processed 993 instances
# processed 994 instances
# processed 995 instances
# processed 996 instances
# processed 997 instances
# processed 998 instances
# processed 999 instances
# processed 1001 instances
# processed 1002 instances
# processed 1003 instances
# processed 1004 instances
# processed 1005 instances
# processed 1006 instances
# processed 1007 instances
# processed 1008 instances
# processed 1009 instances
# processed 1010 instances
# processed 1011 instances
# processed 1012 instances
# processed 1013 instances
# processed 1014 instances
# processed 1015 instances
# processed 1016 instances
# processed 1017 instances
# processed 1018 instances
# processed 1019 instances
# processed 1020 instances
# processed 1021 instances
# processed 1022 instances
# processed 1023 instances
# processed 1024 instances
# processed 1025 instances
# processed 1026 instances
# processed 1027 instances
# processed 1028 instances
# processed 1029 instances
# processed 1030 instances
# processed 1031 instances
# processed 1032 instances
# processed 1033 instances
# processed 1034 instances
# processed 1035 instances
# processed 1036 instances
# processed 1037 instances
# processed 1038 instances
# processed 1039 instances
# processed 1040 instances
# processed 1041 instances
# processed 1042 instances
# processed 1043 instances
# processed 1044 instances
# processed 1045 instances
# processed 1046 instances
# processed 1047 instances
# processed 1048 instances
# processed 1049 instances
# processed 1050 instances
# processed 1051 instances
# processed 1052 instances
# processed 1053 instances
# processed 1054 instances
# processed 1055 instances
# processed 1056 instances
# processed 1057 instances
# processed 1058 instances
# processed 1059 instances
# processed 1060 instances
# processed 1061 instances
# processed 1062 instances
# processed 1063 instances
# processed 1064 instances
# processed 1065 instances
# processed 1066 instances
# processed 1067 instances
# processed 1068 instances
# processed 1069 instances
# processed 1070 instances
# processed 1071 instances
# processed 1072 instances
# processed 1073 instances
# processed 1074 instances
# processed 1075 instances
# processed 1076 instances
# processed 1077 instances
# processed 1078 instances
# processed 1079 instances
# processed 1080 instances
# processed 1081 instances
# processed 1082 instances
# processed 1083 instances
# processed 1084 instances
# processed 1085 instances
# processed 1086 instances
# processed 1087 instances
# processed 1088 instances
# processed 1089 instances
# processed 1090 instances
# processed 1091 instances
# processed 1092 instances
# processed 1093 instances
# processed 1094 instances
# processed 1095 instances
# processed 1096 instances
# processed 1097 instances
# processed 1098 instances
# processed 1099 instances
# processed 1101 instances
# processed 1102 instances
# processed 1103 instances
# processed 1104 instances
# processed 1105 instances
# processed 1106 instances
# processed 1107 instances
# processed 1108 instances
# processed 1109 instances
# processed 1110 instances
# processed 1111 instances
# processed 1112 instances
# processed 1113 instances
# processed 1114 instances
# processed 1115 instances
# processed 1116 instances
# processed 1117 instances
# processed 1118 instances
# processed 1119 instances
# processed 1120 instances
# processed 1121 instances
# processed 1122 instances
# processed 1123 instances
# processed 1124 instances
# processed 1125 instances
# processed 1126 instances
# processed 1127 instances
# processed 1128 instances
# processed 1129 instances
# processed 1130 instances
# processed 1131 instances
# processed 1132 instances
# processed 1133 instances
# processed 1134 instances
# processed 1135 instances
# processed 1136 instances
# processed 1137 instances
# processed 1138 instances
# processed 1139 instances
# processed 1140 instances
# processed 1141 instances
# processed 1142 instances
# processed 1143 instances
# processed 1144 instances
# processed 1145 instances
# processed 1146 instances
# processed 1147 instances
# processed 1148 instances
# processed 1149 instances
# processed 1150 instances
# processed 1151 instances
# processed 1152 instances
# processed 1153 instances
# processed 1154 instances
# processed 1155 instances
# processed 1156 instances
# processed 1157 instances
# processed 1158 instances
# processed 1159 instances
# processed 1160 instances
# processed 1161 instances
# processed 1162 instances
# processed 1163 instances
# processed 1164 instances
# processed 1165 instances
# processed 1166 instances
# processed 1167 instances
# processed 1168 instances
# processed 1169 instances
# processed 1170 instances
# processed 1171 instances
# processed 1172 instances
# processed 1173 instances
# processed 1174 instances
# processed 1175 instances
# processed 1176 instances
# processed 1177 instances
# processed 1178 instances
# processed 1179 instances
# processed 1180 instances
# processed 1181 instances
# processed 1182 instances
# processed 1183 instances
# processed 1184 instances
# processed 1185 instances
# processed 1186 instances
# processed 1187 instances
# processed 1188 instances
# processed 1189 instances
# processed 1190 instances
# processed 1191 instances
# processed 1192 instances
# processed 1193 instances
# processed 1194 instances
# processed 1195 instances
# processed 1196 instances
# processed 1197 instances
# processed 1198 instances
# processed 1199 instances
# processed 1201 instances
# processed 1202 instances
# processed 1203 instances
# processed 1204 instances
# processed 1205 instances
# processed 1206 instances
# processed 1207 instances
# processed 1208 instances
# processed 1209 instances
# processed 1210 instances
# processed 1211 instances
# processed 1212 instances
# processed 1213 instances
# processed 1214 instances
# processed 1215 instances
# processed 1216 instances
# processed 1217 instances
# processed 1218 instances
# processed 1219 instances
# processed 1220 instances
# processed 1221 instances
# processed 1222 instances
# processed 1223 instances
# processed 1224 instances
# processed 1225 instances
# processed 1226 instances
# processed 1227 instances
# processed 1228 instances
# processed 1229 instances
# processed 1230 instances
# processed 1231 instances
# processed 1232 instances
# processed 1233 instances
# processed 1234 instances
# processed 1235 instances
# processed 1236 instances
# processed 1237 instances
# processed 1238 instances
# processed 1239 instances
# processed 1240 instances
# processed 1241 instances
# processed 1242 instances
# processed 1243 instances
# processed 1244 instances
# processed 1245 instances
# processed 1246 instances
# processed 1247 instances
# processed 1248 instances
# processed 1249 instances
# processed 1250 instances
# processed 1251 instances
# processed 1252 instances
# processed 1253 instances
# processed 1254 instances
# processed 1255 instances
# processed 1256 instances
# processed 1257 instances
# processed 1258 instances
# processed 1259 instances
# processed 1260 instances
# processed 1261 instances
# processed 1262 instances
# processed 1263 instances
# processed 1264 instances
# processed 1265 instances
# processed 1266 instances
# processed 1267 instances
# processed 1268 instances
# processed 1269 instances
# processed 1270 instances
# processed 1271 instances
# processed 1272 instances
# processed 1273 instances
# processed 1274 instances
# processed 1275 instances
# processed 1276 instances
# processed 1277 instances
# processed 1278 instances
# processed 1279 instances
# processed 1280 instances
# processed 1281 instances
# processed 1282 instances
# processed 1283 instances
# processed 1284 instances
# processed 1285 instances
# processed 1286 instances
# processed 1287 instances
# processed 1288 instances
# processed 1289 instances
# processed 1290 instances
# processed 1291 instances
# processed 1292 instances
# processed 1293 instances
# processed 1294 instances
# processed 1295 instances
# processed 1296 instances
# processed 1297 instances
# processed 1298 instances
# processed 1299 instances
# processed 1301 instances
# processed 1302 instances
# processed 1303 instances
# processed 1304 instances
# processed 1305 instances
# processed 1306 instances
# processed 1307 instances
# processed 1308 instances
# processed 1309 instances
# processed 1310 instances
# processed 1311 instances
# processed 1312 instances
# processed 1313 instances
# processed 1314 instances
# processed 1315 instances
# processed 1316 instances
# processed 1317 instances
# processed 1318 instances
# processed 1319 instances
# processed 1320 instances
# processed 1321 instances
# processed 1322 instances
# processed 1323 instances
# processed 1324 instances
# processed 1325 instances
# processed 1326 instances
# processed 1327 instances
# processed 1328 instances
# processed 1329 instances
# processed 1330 instances
# processed 1331 instances
# processed 1332 instances
# processed 1333 instances
# processed 1334 instances
# processed 1335 instances
# processed 1336 instances
# processed 1337 instances
# processed 1338 instances
# processed 1339 instances
# processed 1340 instances
# processed 1341 instances
# processed 1342 instances
# processed 1343 instances
# processed 1344 instances
# processed 1345 instances
# processed 1346 instances
# processed 1347 instances
# processed 1348 instances
# processed 1349 instances
# processed 1350 instances
# processed 1351 instances
# processed 1352 instances
# processed 1353 instances
# processed 1354 instances
# processed 1355 instances
# processed 1356 instances
# processed 1357 instances
# processed 1358 instances
# processed 1359 instances
# processed 1360 instances
# processed 1361 instances
# processed 1362 instances
# processed 1363 instances
# processed 1364 instances
# processed 1365 instances
# processed 1366 instances
# processed 1367 instances
# processed 1368 instances
# processed 1369 instances
# processed 1370 instances
# processed 1371 instances
# processed 1372 instances
# processed 1373 instances
# processed 1374 instances
# processed 1375 instances
# processed 1376 instances
# processed 1377 instances
# processed 1378 instances
# processed 1379 instances
# processed 1380 instances
# processed 1381 instances
# processed 1382 instances
# processed 1383 instances
# processed 1384 instances
# processed 1385 instances
# processed 1386 instances
# processed 1387 instances
# processed 1388 instances
# processed 1389 instances
# processed 1390 instances
# processed 1391 instances
# processed 1392 instances
# processed 1393 instances
# processed 1394 instances
# processed 1395 instances
# processed 1396 instances
# processed 1397 instances
# processed 1398 instances
# processed 1399 instances
# processed 1401 instances
# processed 1402 instances
# processed 1403 instances
# processed 1404 instances
# processed 1405 instances
# processed 1406 instances
# processed 1407 instances
# processed 1408 instances
# processed 1409 instances
# processed 1410 instances
# processed 1411 instances
# processed 1412 instances
# processed 1413 instances
# processed 1414 instances
# processed 1415 instances
# processed 1416 instances
# processed 1417 instances
# processed 1418 instances
# processed 1419 instances
# processed 1420 instances
# processed 1421 instances
# processed 1422 instances
# processed 1423 instances
# processed 1424 instances
# processed 1425 instances
# processed 1426 instances
# processed 1427 instances
# processed 1428 instances
# processed 1429 instances
# processed 1430 instances
# processed 1431 instances
# processed 1432 instances
# processed 1433 instances
# processed 1434 instances
# processed 1435 instances
# processed 1436 instances
# processed 1437 instances
# processed 1438 instances
# processed 1439 instances
# processed 1440 instances
# processed 1441 instances
# processed 1442 instances
# processed 1443 instances
# processed 1444 instances
# processed 1445 instances
# processed 1446 instances
# processed 1447 instances
# processed 1448 instances
# processed 1449 instances
# processed 1450 instances
# processed 1451 instances
# processed 1452 instances
# processed 1453 instances
# processed 1454 instances
# processed 1455 instances
# processed 1456 instances
# processed 1457 instances
# processed 1458 instances
# processed 1459 instances
# processed 1460 instances
# processed 1461 instances
# processed 1462 instances
# processed 1463 instances
# processed 1464 instances
# processed 1465 instances
# processed 1466 instances
# processed 1467 instances
# processed 1468 instances
# processed 1469 instances
# processed 1470 instances
# processed 1471 instances
# processed 1472 instances
# processed 1473 instances
# processed 1474 instances
# processed 1475 instances
# processed 1476 instances
# processed 1477 instances
# processed 1478 instances
# processed 1479 instances
# processed 1480 instances
# processed 1481 instances
# processed 1482 instances
# processed 1483 instances
# processed 1484 instances
# processed 1485 instances
# processed 1486 instances
# processed 1487 instances
# processed 1488 instances
# processed 1489 instances
# processed 1490 instances
# processed 1491 instances
# processed 1492 instances
# processed 1493 instances
# processed 1494 instances
# processed 1495 instances
# processed 1496 instances
# processed 1497 instances
# processed 1498 instances
# processed 1499 instances
# processed 1501 instances
# processed 1502 instances
# processed 1503 instances
# processed 1504 instances
# processed 1505 instances
# processed 1506 instances
# processed 1507 instances
# processed 1508 instances
# processed 1509 instances
# processed 1510 instances
# processed 1511 instances
# processed 1512 instances
# processed 1513 instances
# processed 1514 instances
# processed 1515 instances
# processed 1516 instances
# processed 1517 instances
# processed 1518 instances
# processed 1519 instances
# processed 1520 instances
# processed 1521 instances
# processed 1522 instances
# processed 1523 instances
# processed 1524 instances
# processed 1525 instances
# processed 1526 instances
# processed 1527 instances
# processed 1528 instances
# processed 1529 instances
# processed 1530 instances
# processed 1531 instances
# processed 1532 instances
# processed 1533 instances
# processed 1534 instances
# processed 1535 instances
# processed 1536 instances
# processed 1537 instances
# processed 1538 instances
# processed 1539 instances
# processed 1540 instances
# processed 1541 instances
# processed 1542 instances
# processed 1543 instances
# processed 1544 instances
# processed 1545 instances
# processed 1546 instances
# processed 1547 instances
# processed 1548 instances
# processed 1549 instances
# processed 1550 instances
# processed 1551 instances
# processed 1552 instances
# processed 1553 instances
# processed 1554 instances
# processed 1555 instances
# processed 1556 instances
# processed 1557 instances
# processed 1558 instances
# processed 1559 instances
# processed 1560 instances
# processed 1561 instances
# processed 1562 instances
# processed 1563 instances
# processed 1564 instances
# processed 1565 instances
# processed 1566 instances
# processed 1567 instances
# processed 1568 instances
# processed 1569 instances
# processed 1570 instances
# processed 1571 instances
# processed 1572 instances
# processed 1573 instances
# processed 1574 instances
# processed 1575 instances
# processed 1576 instances
# processed 1577 instances
# processed 1578 instances
# processed 1579 instances
# processed 1580 instances
# processed 1581 instances
# processed 1582 instances
# processed 1583 instances
# processed 1584 instances
# processed 1585 instances
# processed 1586 instances
# processed 1587 instances
# processed 1588 instances
# processed 1589 instances
# processed 1590 instances
# processed 1591 instances
# processed 1592 instances
# processed 1593 instances
# processed 1594 instances
# processed 1595 instances
# processed 1596 instances
# processed 1597 instances
# processed 1598 instances
# processed 1599 instances
# processed 1601 instances
# processed 1602 instances
# processed 1603 instances
# processed 1604 instances
# processed 1605 instances
# processed 1606 instances
# processed 1607 instances
# processed 1608 instances
# processed 1609 instances
# processed 1610 instances
# processed 1611 instances
# processed 1612 instances
# processed 1613 instances
# processed 1614 instances
# processed 1615 instances
# processed 1616 instances
# processed 1617 instances
# processed 1618 instances
# processed 1619 instances
# processed 1620 instances
# processed 1621 instances
# processed 1622 instances
# processed 1623 instances
# processed 1624 instances
# processed 1625 instances
# processed 1626 instances
# processed 1627 instances
# processed 1628 instances
# processed 1629 instances
# processed 1630 instances
# processed 1631 instances
# processed 1632 instances
# processed 1633 instances
# processed 1634 instances
# processed 1635 instances
# processed 1636 instances
# processed 1637 instances
# processed 1638 instances
# processed 1639 instances
# processed 1640 instances
# processed 1641 instances
# processed 1642 instances
# processed 1643 instances
# processed 1644 instances
# processed 1645 instances
# processed 1646 instances
# processed 1647 instances
# processed 1648 instances
# processed 1649 instances
# processed 1650 instances
# processed 1651 instances
# processed 1652 instances
# processed 1653 instances
# processed 1654 instances
# processed 1655 instances
# processed 1656 instances
# processed 1657 instances
# processed 1658 instances
# processed 1659 instances
# processed 1660 instances
# processed 1661 instances
# processed 1662 instances
# processed 1663 instances
# processed 1664 instances
# processed 1665 instances
# processed 1666 instances
# processed 1667 instances
# processed 1668 instances
# processed 1669 instances
# processed 1670 instances
# processed 1671 instances
# processed 1672 instances
# processed 1673 instances
# processed 1674 instances
# processed 1675 instances
# processed 1676 instances
# processed 1677 instances
# processed 1678 instances
# processed 1679 instances
# processed 1680 instances
# processed 1681 instances
# processed 1682 instances
# processed 1683 instances
# processed 1684 instances
# processed 1685 instances
# processed 1686 instances
# processed 1687 instances
# processed 1688 instances
# processed 1689 instances
# processed 1690 instances
# processed 1691 instances
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       2 if i % 100:
#       3    print('processed',str(i),'instances')
# ----> 4 res = requests.post('http://localhost:11434/api/embeddings',
#       5                   json={
#       6                       'model':'llama2',
#       7                       'prompt':representation
#       8                   }
#       9                   )
#      10 embedding = res.json()['embedding']
#      11 X[i] = np.array(embedding)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#     509 except BrokenPipeError:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:398, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     396 for header, value in headers.items():
#     397     self.putheader(header, value)
# --> 398 self.endheaders()
#     400 # If we're given a body we start sending that in chunks.
#     401 if chunks is not None:
#
# File ~\anaconda3\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1329 else:
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1089 msg = b"\r\n".join(self._buffer)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#    1096     if hasattr(message_body, 'read'):
#    1097         # Let file-like take precedence over byte-like.  This
#    1098         # is needed to allow the current position of mmap'ed
#    1099         # files to be taken into account.
#
# File ~\anaconda3\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1033 if self.sock is None:
#    1034     if self.auto_open:
# -> 1035         self.connect()
#    1036     else:
#    1037         raise NotConnected()
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:236, in HTTPConnection.connect(self)
#     235 def connect(self) -> None:
# --> 236     self.sock = self._new_conn()
#     237     if self._tunnel_host:
#     238         # If we're tunneling it means we're connected to our proxy.
#     239         self._has_connected_to_proxy = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File ~\anaconda3\Lib\socket.py:501, in socket.close(self)
#     497 def _real_close(self, _ss=_socket.socket):
#     498     # This function should not reference any globals. See issue #808164.
#     499     _ss.close(self)
# --> 501 def close(self):
#     502     # This function should not reference any globals. See issue #808164.
#     503     self._closed = True
#     504     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
faiss.write_index(index,'index')

# %%
index = faiss.read_index('index')

# %%
df[df.title.str.contains('Shutter')]
# Out:
#      show_id   type           title                                  director  \
# 1358   s1359  Movie  Shutter Island                           Martin Scorsese
# 8013   s8014  Movie         Shutter  Banjong Pisanthanakun, Parkpoom Wongpoom
#
#                                                    cast        country  \
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...  United States
# 8013  Ananda Everingham, Natthaweeranuch Thongmee, A...       Thailand
#
#              date_added  release_year rating duration  \
# 1358   February 1, 2021          2010      R  139 min
# 8013  September 5, 2018          2004  TV-MA   96 min
#
#                                 listed_in  \
# 1358                            Thrillers
# 8013  Horror Movies, International Movies
#
#                                             description  \
# 1358  A U.S. marshal's troubling visions compromise ...
# 8013  After killing a young girl in a hit-and-run ac...
#
#                                  textual_representation
# 1358  \n    Type: Movie,\n    Title: Shutter Island,...
# 8013  \n    Type: Movie,\n    Title: Shutter,\n    D...

# %%
favorite_movie = df.iloc[800]

# %%
res = requests.post('http://localhost:11434/api/embeddings',
                      json={
                          'model':'llama2',
                          'prompt':favorite_movie['textual_representation']
                      }
                      )

# %%
embedding = np.array([res.json()['embedding']], dtype='float32')
D,I = index.search(embedding,5)

# %%
best_matchs = np.array(df['textual_representation'])[I.flatten()]

# %%
for match in best_matchs:
    print("NEXT MOVIE")
    print(match)
    print('-'*100)
# Out:
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------

# %%
new_movie = '''Type: family,
    Title: Dick Johnson Is Dead,
    Director: Kirsten Johnson,
    Cast: nan,
    Release Year: 2020,
    Listed In: Documentaries,
    Description: As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.'''

# %%
res = requests.post('http://localhost:11434/api/embeddings',
                      json={
                          'model':'llama2',
                          'prompt':new_movie
                      }
                      )

# %%
embedding = np.array([res.json()['embedding']], dtype='float32')
D,I = index.search(embedding,5)

# %%
best_matchs = np.array(df['textual_representation'])[I.flatten()]

# %%
for match in best_matchs:
    print("NEXT MOVIE")
    print(match)
    print('-'*100)
# Out:
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
# NEXT MOVIE
#
#     Type: Movie,
#     Title: Zubaan,
#     Director: Mozez Singh,
#     Cast: Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy,
#     Release Year: 2015,
#     Listed In: Dramas, International Movies, Music & Musicals,
#     Description: A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.
#
# ----------------------------------------------------------------------------------------------------
