# %%
import numpy as np
import keras
import os
from pathlib import Path

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = '/content/ara.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32",
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 94
# Max sequence length for inputs: 36
# Max sequence length for outputs: 54

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s_model.keras")
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6742 - loss: 1.7358 - val_accuracy: 0.5848 - val_loss: 1.9716
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7132 - loss: 1.1414 - val_accuracy: 0.5942 - val_loss: 1.5534
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7254 - loss: 1.0529 - val_accuracy: 0.6135 - val_loss: 1.4568
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7419 - loss: 0.9850 - val_accuracy: 0.6295 - val_loss: 1.4032
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7551 - loss: 0.9292 - val_accuracy: 0.6472 - val_loss: 1.3278
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7624 - loss: 0.8933 - val_accuracy: 0.6518 - val_loss: 1.3000
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7648 - loss: 0.8927 - val_accuracy: 0.6588 - val_loss: 1.2766
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7722 - loss: 0.8487 - val_accuracy: 0.6646 - val_loss: 1.2477
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7758 - loss: 0.8297 - val_accuracy: 0.6635 - val_loss: 1.2414
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7787 - loss: 0.8187 - val_accuracy: 0.6735 - val_loss: 1.2079
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7796 - loss: 0.8108 - val_accuracy: 0.6700 - val_loss: 1.2051
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7815 - loss: 0.8025 - val_accuracy: 0.6757 - val_loss: 1.1867
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7844 - loss: 0.7922 - val_accuracy: 0.6706 - val_loss: 1.2001
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7881 - loss: 0.7763 - val_accuracy: 0.6767 - val_loss: 1.1722
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7877 - loss: 0.7755 - val_accuracy: 0.6844 - val_loss: 1.1555
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7892 - loss: 0.7696 - val_accuracy: 0.6845 - val_loss: 1.1474
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7935 - loss: 0.7533 - val_accuracy: 0.6873 - val_loss: 1.1450
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7947 - loss: 0.7474 - val_accuracy: 0.6920 - val_loss: 1.1215
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7975 - loss: 0.7366 - val_accuracy: 0.6888 - val_loss: 1.1262
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7993 - loss: 0.7311 - val_accuracy: 0.6930 - val_loss: 1.1136
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7989 - loss: 0.7293 - val_accuracy: 0.6930 - val_loss: 1.1114
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8014 - loss: 0.7200 - val_accuracy: 0.6938 - val_loss: 1.1030
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8020 - loss: 0.7145 - val_accuracy: 0.6956 - val_loss: 1.0959
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8042 - loss: 0.7083 - val_accuracy: 0.6983 - val_loss: 1.0901
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8041 - loss: 0.7061 - val_accuracy: 0.6999 - val_loss: 1.0812
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8083 - loss: 0.6946 - val_accuracy: 0.7023 - val_loss: 1.0763
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8103 - loss: 0.6848 - val_accuracy: 0.7022 - val_loss: 1.0717
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8116 - loss: 0.6818 - val_accuracy: 0.7094 - val_loss: 1.0560
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8135 - loss: 0.6733 - val_accuracy: 0.7048 - val_loss: 1.0637
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8153 - loss: 0.6659 - val_accuracy: 0.7078 - val_loss: 1.0577
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8182 - loss: 0.6563 - val_accuracy: 0.7113 - val_loss: 1.0420
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8194 - loss: 0.6530 - val_accuracy: 0.7129 - val_loss: 1.0415
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8206 - loss: 0.6485 - val_accuracy: 0.7169 - val_loss: 1.0305
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8232 - loss: 0.6378 - val_accuracy: 0.7146 - val_loss: 1.0329
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8246 - loss: 0.6308 - val_accuracy: 0.7182 - val_loss: 1.0261
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8266 - loss: 0.6247 - val_accuracy: 0.7222 - val_loss: 1.0132
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8287 - loss: 0.6182 - val_accuracy: 0.7213 - val_loss: 1.0160
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8301 - loss: 0.6133 - val_accuracy: 0.7192 - val_loss: 1.0175
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8326 - loss: 0.6060 - val_accuracy: 0.7245 - val_loss: 1.0075
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8342 - loss: 0.5977 - val_accuracy: 0.7232 - val_loss: 1.0072
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8357 - loss: 0.5917 - val_accuracy: 0.7252 - val_loss: 1.0050
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8383 - loss: 0.5839 - val_accuracy: 0.7241 - val_loss: 1.0059
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8395 - loss: 0.5814 - val_accuracy: 0.7277 - val_loss: 0.9955
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8399 - loss: 0.5767 - val_accuracy: 0.7277 - val_loss: 0.9952
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8424 - loss: 0.5705 - val_accuracy: 0.7272 - val_loss: 0.9979
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8435 - loss: 0.5669 - val_accuracy: 0.7273 - val_loss: 0.9986
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8451 - loss: 0.5606 - val_accuracy: 0.7316 - val_loss: 0.9916
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8451 - loss: 0.5606 - val_accuracy: 0.7288 - val_loss: 0.9968
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8473 - loss: 0.5543 - val_accuracy: 0.7298 - val_loss: 0.9983
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8480 - loss: 0.5502 - val_accuracy: 0.7274 - val_loss: 1.0033
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8495 - loss: 0.5427 - val_accuracy: 0.7315 - val_loss: 0.9948
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8511 - loss: 0.5370 - val_accuracy: 0.7314 - val_loss: 0.9925
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8515 - loss: 0.5347 - val_accuracy: 0.7270 - val_loss: 1.0149
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8534 - loss: 0.5309 - val_accuracy: 0.7306 - val_loss: 1.0011
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8562 - loss: 0.5201 - val_accuracy: 0.7316 - val_loss: 0.9978
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8564 - loss: 0.5178 - val_accuracy: 0.7300 - val_loss: 1.0029
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8578 - loss: 0.5127 - val_accuracy: 0.7323 - val_loss: 0.9989
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8591 - loss: 0.5090 - val_accuracy: 0.7328 - val_loss: 0.9983
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8590 - loss: 0.5085 - val_accuracy: 0.7316 - val_loss: 1.0045
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8623 - loss: 0.4987 - val_accuracy: 0.7295 - val_loss: 1.0103
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8616 - loss: 0.4979 - val_accuracy: 0.7312 - val_loss: 1.0120
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8635 - loss: 0.4927 - val_accuracy: 0.7312 - val_loss: 1.0132
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8647 - loss: 0.4890 - val_accuracy: 0.7321 - val_loss: 1.0119
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8666 - loss: 0.4798 - val_accuracy: 0.7313 - val_loss: 1.0185
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8678 - loss: 0.4786 - val_accuracy: 0.7317 - val_loss: 1.0204
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8684 - loss: 0.4752 - val_accuracy: 0.7332 - val_loss: 1.0170
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8714 - loss: 0.4678 - val_accuracy: 0.7319 - val_loss: 1.0261
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8717 - loss: 0.4645 - val_accuracy: 0.7309 - val_loss: 1.0324
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8722 - loss: 0.4597 - val_accuracy: 0.7333 - val_loss: 1.0276
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8741 - loss: 0.4548 - val_accuracy: 0.7322 - val_loss: 1.0332
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8744 - loss: 0.4517 - val_accuracy: 0.7309 - val_loss: 1.0473
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8764 - loss: 0.4460 - val_accuracy: 0.7318 - val_loss: 1.0402
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8774 - loss: 0.4410 - val_accuracy: 0.7306 - val_loss: 1.0478
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8780 - loss: 0.4386 - val_accuracy: 0.7304 - val_loss: 1.0526
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8797 - loss: 0.4347 - val_accuracy: 0.7319 - val_loss: 1.0517
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8811 - loss: 0.4277 - val_accuracy: 0.7315 - val_loss: 1.0544
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8821 - loss: 0.4249 - val_accuracy: 0.7296 - val_loss: 1.0605
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8829 - loss: 0.4211 - val_accuracy: 0.7281 - val_loss: 1.0789
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8844 - loss: 0.4170 - val_accuracy: 0.7291 - val_loss: 1.0810
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8865 - loss: 0.4103 - val_accuracy: 0.7283 - val_loss: 1.0888
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8883 - loss: 0.4027 - val_accuracy: 0.7291 - val_loss: 1.0801
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8875 - loss: 0.4054 - val_accuracy: 0.7273 - val_loss: 1.0982
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8888 - loss: 0.4011 - val_accuracy: 0.7291 - val_loss: 1.0969
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8897 - loss: 0.3973 - val_accuracy: 0.7284 - val_loss: 1.1114
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8916 - loss: 0.3905 - val_accuracy: 0.7294 - val_loss: 1.1000
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8920 - loss: 0.3903 - val_accuracy: 0.7283 - val_loss: 1.1065
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8933 - loss: 0.3839 - val_accuracy: 0.7289 - val_loss: 1.1146
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8939 - loss: 0.3836 - val_accuracy: 0.7264 - val_loss: 1.1325
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8949 - loss: 0.3782 - val_accuracy: 0.7274 - val_loss: 1.1320
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8960 - loss: 0.3745 - val_accuracy: 0.7264 - val_loss: 1.1379
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8975 - loss: 0.3706 - val_accuracy: 0.7279 - val_loss: 1.1404
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8981 - loss: 0.3680 - val_accuracy: 0.7255 - val_loss: 1.1514
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9002 - loss: 0.3604 - val_accuracy: 0.7265 - val_loss: 1.1586
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8997 - loss: 0.3610 - val_accuracy: 0.7271 - val_loss: 1.1555
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9017 - loss: 0.3556 - val_accuracy: 0.7256 - val_loss: 1.1664
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9015 - loss: 0.3544 - val_accuracy: 0.7262 - val_loss: 1.1687
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9020 - loss: 0.3524 - val_accuracy: 0.7250 - val_loss: 1.1771
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9037 - loss: 0.3464 - val_accuracy: 0.7238 - val_loss: 1.1861
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9047 - loss: 0.3426 - val_accuracy: 0.7244 - val_loss: 1.1903
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9052 - loss: 0.3433 - val_accuracy: 0.7258 - val_loss: 1.1884

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s_model.keras")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq, verbose=0)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value, verbose=0
        )

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Hi.
# Decoded sentence: استرح.
#
# -
# Input sentence: Run!
# Decoded sentence: العض الخافئة.
#
# -
# Input sentence: Duck!
# Decoded sentence: استرح.
#
# -
# Input sentence: Duck!
# Decoded sentence: استرح.
#
# -
# Input sentence: Duck!
# Decoded sentence: استرح.
#
# -
# Input sentence: Help!
# Decoded sentence: استرد.
#
# -
# Input sentence: Jump!
# Decoded sentence: أوقف ذلك.
#
# -
# Input sentence: Stop!
# Decoded sentence: أوقف ذلك.
#
# -
# Input sentence: Stop!
# Decoded sentence: أوقف ذلك.
#
# -
# Input sentence: Wait!
# Decoded sentence: ما الذي حصل؟
#
# -
# Input sentence: Go on.
# Decoded sentence: التلاحة.
#
# -
# Input sentence: Go on.
# Decoded sentence: التلاحة.
#
# -
# Input sentence: Hello!
# Decoded sentence: استماع.
#
# -
# Input sentence: Hello.
# Decoded sentence: استماع.
#
# -
# Input sentence: Hello.
# Decoded sentence: استماع.
#
# -
# Input sentence: Hurry!
# Decoded sentence: استعاج!
#
# -
# Input sentence: Hurry!
# Decoded sentence: استعاج!
#
# -
# Input sentence: I see.
# Decoded sentence: انه يوم.
#
# -
# Input sentence: I won!
# Decoded sentence: أنا أحبها
#
# -
# Input sentence: Relax.
# Decoded sentence: الحلاب!
