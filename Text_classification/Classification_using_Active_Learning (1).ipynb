# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"  # @param ["tensorflow", "jax", "torch"]
import keras
from keras import ops
from keras import layers
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Total examples: 50000

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %%
vectorizer = layers.TextVectorization(
    3000, standardize="lower_and_strip_punctuation", output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.keras", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.keras")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 150, 128)            │         384,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 150, 64)             │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d                 │ (None, 64)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 20)                  │           1,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - binary_accuracy: 0.6515 - false_negatives: 2005.5988 - false_positives: 5130.9619 - loss: 0.6412
# Epoch 1: val_loss improved from inf to 0.56371, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - binary_accuracy: 0.6515 - false_negatives: 2028.4493 - false_positives: 5151.2910 - loss: 0.6412 - val_binary_accuracy: 0.7306 - val_false_negatives: 981.0000 - val_false_positives: 366.0000 - val_loss: 0.5637
# Epoch 2/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.7636 - false_negatives: 1703.6987 - false_positives: 2991.2820 - loss: 0.5180
# Epoch 2: val_loss improved from 0.56371 to 0.42850, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - binary_accuracy: 0.7637 - false_negatives: 1729.8291 - false_positives: 3021.5442 - loss: 0.5178 - val_binary_accuracy: 0.8168 - val_false_negatives: 543.0000 - val_false_positives: 373.0000 - val_loss: 0.4285
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8182 - false_negatives: 1556.7961 - false_positives: 2128.4395 - loss: 0.4245
# Epoch 3: val_loss did not improve from 0.42850
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.8181 - false_negatives: 1568.2784 - false_positives: 2139.9873 - loss: 0.4245 - val_binary_accuracy: 0.7812 - val_false_negatives: 984.0000 - val_false_positives: 110.0000 - val_loss: 0.4665
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8383 - false_negatives: 1467.0574 - false_positives: 1757.7579 - loss: 0.3860
# Epoch 4: val_loss improved from 0.42850 to 0.37194, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - binary_accuracy: 0.8383 - false_negatives: 1477.4937 - false_positives: 1767.5316 - loss: 0.3860 - val_binary_accuracy: 0.8352 - val_false_negatives: 597.0000 - val_false_positives: 227.0000 - val_loss: 0.3719
# Epoch 5/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8551 - false_negatives: 1338.2903 - false_positives: 1581.4517 - loss: 0.3552
# Epoch 5: val_loss did not improve from 0.37194
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - binary_accuracy: 0.8550 - false_negatives: 1367.7532 - false_positives: 1609.4493 - loss: 0.3553 - val_binary_accuracy: 0.8060 - val_false_negatives: 845.0000 - val_false_positives: 125.0000 - val_loss: 0.4292
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8638 - false_negatives: 1300.7261 - false_positives: 1435.5605 - loss: 0.3348
# Epoch 6: val_loss improved from 0.37194 to 0.34183, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - binary_accuracy: 0.8638 - false_negatives: 1309.7595 - false_positives: 1443.8354 - loss: 0.3349 - val_binary_accuracy: 0.8512 - val_false_negatives: 451.0000 - val_false_positives: 293.0000 - val_loss: 0.3418
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8773 - false_negatives: 1175.4395 - false_positives: 1323.5223 - loss: 0.3095
# Epoch 7: val_loss improved from 0.34183 to 0.33736, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - binary_accuracy: 0.8773 - false_negatives: 1183.8607 - false_positives: 1331.3987 - loss: 0.3096 - val_binary_accuracy: 0.8496 - val_false_negatives: 413.0000 - val_false_positives: 339.0000 - val_loss: 0.3374
# Epoch 8/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8840 - false_negatives: 1098.6581 - false_positives: 1253.7355 - loss: 0.2971
# Epoch 8: val_loss improved from 0.33736 to 0.33057, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.8838 - false_negatives: 1123.7152 - false_positives: 1276.5127 - loss: 0.2973 - val_binary_accuracy: 0.8554 - val_false_negatives: 409.0000 - val_false_positives: 314.0000 - val_loss: 0.3306
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8896 - false_negatives: 1090.8662 - false_positives: 1192.9937 - loss: 0.2857
# Epoch 9: val_loss did not improve from 0.33057
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - binary_accuracy: 0.8896 - false_negatives: 1098.4620 - false_positives: 1200.0316 - loss: 0.2857 - val_binary_accuracy: 0.8454 - val_false_negatives: 197.0000 - val_false_positives: 576.0000 - val_loss: 0.3555
# Epoch 10/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8967 - false_negatives: 1004.6968 - false_positives: 1121.1161 - loss: 0.2705
# Epoch 10: val_loss did not improve from 0.33057
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - binary_accuracy: 0.8965 - false_negatives: 1026.5253 - false_positives: 1141.5759 - loss: 0.2706 - val_binary_accuracy: 0.8382 - val_false_negatives: 164.0000 - val_false_positives: 645.0000 - val_loss: 0.3925
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8988 - false_negatives: 963.3630 - false_positives: 1089.1910 - loss: 0.2601
# Epoch 11: val_loss did not improve from 0.33057
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.8987 - false_negatives: 970.3734 - false_positives: 1095.6013 - loss: 0.2602 - val_binary_accuracy: 0.8528 - val_false_negatives: 461.0000 - val_false_positives: 275.0000 - val_loss: 0.3379
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9043 - false_negatives: 942.6815 - false_positives: 1033.4141 - loss: 0.2506
# Epoch 12: val_loss did not improve from 0.33057
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - binary_accuracy: 0.9043 - false_negatives: 949.6646 - false_positives: 1039.4557 - loss: 0.2507 - val_binary_accuracy: 0.8492 - val_false_negatives: 508.0000 - val_false_positives: 246.0000 - val_loss: 0.3490
# Epoch 12: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8533999919891357, 'false_negatives': 434.0, 'false_positives': 299.0, 'loss': 0.3320835828781128}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.keras", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = ops.where(ops.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.keras")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 150, 128)            │         384,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 150, 64)             │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_1               │ (None, 64)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20)                  │           1,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting to train with 15000 samples
# Epoch 1/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.5169 - false_negatives_1: 2550.9312 - false_positives_1: 1059.6207 - loss: 0.6919
# Epoch 1: val_loss improved from inf to 0.67790, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - binary_accuracy: 0.5177 - false_negatives_1: 2616.8000 - false_positives_1: 1103.5667 - loss: 0.6918 - val_binary_accuracy: 0.6268 - val_false_negatives_1: 1467.0000 - val_false_positives_1: 399.0000 - val_loss: 0.6779
# Epoch 2/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.6254 - false_negatives_1: 1435.0526 - false_positives_1: 1286.9474 - loss: 0.6634
# Epoch 2: val_loss improved from 0.67790 to 0.58174, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - binary_accuracy: 0.6266 - false_negatives_1: 1492.6500 - false_positives_1: 1356.1500 - loss: 0.6627 - val_binary_accuracy: 0.7376 - val_false_negatives_1: 843.0000 - val_false_positives_1: 469.0000 - val_loss: 0.5817
# Epoch 3/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7087 - false_negatives_1: 946.1896 - false_positives_1: 1251.7759 - loss: 0.5855
# Epoch 3: val_loss did not improve from 0.58174
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - binary_accuracy: 0.7090 - false_negatives_1: 975.3167 - false_positives_1: 1290.7833 - loss: 0.5850 - val_binary_accuracy: 0.6236 - val_false_negatives_1: 31.0000 - val_false_positives_1: 1851.0000 - val_loss: 0.6471
# Epoch 4/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.7527 - false_negatives_1: 688.6610 - false_positives_1: 1175.7627 - loss: 0.5292
# Epoch 4: val_loss improved from 0.58174 to 0.46049, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - binary_accuracy: 0.7529 - false_negatives_1: 700.1000 - false_positives_1: 1193.1000 - loss: 0.5290 - val_binary_accuracy: 0.7968 - val_false_negatives_1: 384.0000 - val_false_positives_1: 632.0000 - val_loss: 0.4605
# Epoch 5/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7916 - false_negatives_1: 682.1552 - false_positives_1: 897.4828 - loss: 0.4665
# Epoch 5: val_loss improved from 0.46049 to 0.42180, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.7916 - false_negatives_1: 704.1500 - false_positives_1: 926.7333 - loss: 0.4665 - val_binary_accuracy: 0.8180 - val_false_negatives_1: 539.0000 - val_false_positives_1: 371.0000 - val_loss: 0.4218
# Epoch 6/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8122 - false_negatives_1: 623.7069 - false_positives_1: 804.1896 - loss: 0.4330
# Epoch 6: val_loss did not improve from 0.42180
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.8122 - false_negatives_1: 644.1833 - false_positives_1: 830.2167 - loss: 0.4331 - val_binary_accuracy: 0.7754 - val_false_negatives_1: 136.0000 - val_false_positives_1: 987.0000 - val_loss: 0.4533
# Epoch 7/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8325 - false_negatives_1: 537.8104 - false_positives_1: 735.4828 - loss: 0.4078
# Epoch 7: val_loss improved from 0.42180 to 0.38115, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - binary_accuracy: 0.8324 - false_negatives_1: 556.6500 - false_positives_1: 758.9667 - loss: 0.4078 - val_binary_accuracy: 0.8408 - val_false_negatives_1: 363.0000 - val_false_positives_1: 433.0000 - val_loss: 0.3811
# Epoch 8/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8444 - false_negatives_1: 536.3621 - false_positives_1: 637.0690 - loss: 0.3776
# Epoch 8: val_loss did not improve from 0.38115
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - binary_accuracy: 0.8443 - false_negatives_1: 554.5833 - false_positives_1: 658.3666 - loss: 0.3775 - val_binary_accuracy: 0.8258 - val_false_negatives_1: 228.0000 - val_false_positives_1: 643.0000 - val_loss: 0.3830
# Epoch 9/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8494 - false_negatives_1: 516.0847 - false_positives_1: 614.2881 - loss: 0.3674
# Epoch 9: val_loss did not improve from 0.38115
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - binary_accuracy: 0.8495 - false_negatives_1: 524.2000 - false_positives_1: 623.8000 - loss: 0.3673 - val_binary_accuracy: 0.8152 - val_false_negatives_1: 204.0000 - val_false_positives_1: 720.0000 - val_loss: 0.3957
# Epoch 10/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8641 - false_negatives_1: 456.3684 - false_positives_1: 552.0702 - loss: 0.3461
# Epoch 10: val_loss did not improve from 0.38115
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8643 - false_negatives_1: 478.4167 - false_positives_1: 579.4833 - loss: 0.3458 - val_binary_accuracy: 0.8338 - val_false_negatives_1: 578.0000 - val_false_positives_1: 253.0000 - val_loss: 0.3865
# Epoch 11/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8795 - false_negatives_1: 419.5172 - false_positives_1: 506.3276 - loss: 0.3164
# Epoch 11: val_loss did not improve from 0.38115
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.8794 - false_negatives_1: 433.7667 - false_positives_1: 522.8500 - loss: 0.3166 - val_binary_accuracy: 0.7738 - val_false_negatives_1: 94.0000 - val_false_positives_1: 1037.0000 - val_loss: 0.5300
# Epoch 11: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 102.0, Number of ones incorrectly classified: 1019.0
# Sample ratio for positives: 0.9090098126672613, Sample ratio for negatives:0.09099018733273863
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.8471 - false_negatives_2: 647.0260 - false_positives_2: 756.5714 - loss: 0.3945
# Epoch 1: val_loss did not improve from 0.38115
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - binary_accuracy: 0.8479 - false_negatives_2: 667.9750 - false_positives_2: 782.9125 - loss: 0.3926 - val_binary_accuracy: 0.8204 - val_false_negatives_2: 188.0000 - val_false_positives_2: 710.0000 - val_loss: 0.3992
# Epoch 2/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8930 - false_negatives_2: 502.9615 - false_positives_2: 598.4103 - loss: 0.2924
# Epoch 2: val_loss did not improve from 0.38115
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - binary_accuracy: 0.8929 - false_negatives_2: 516.2125 - false_positives_2: 614.2000 - loss: 0.2926 - val_binary_accuracy: 0.7346 - val_false_negatives_2: 56.0000 - val_false_positives_2: 1271.0000 - val_loss: 0.6410
# Epoch 3/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8949 - false_negatives_2: 460.0253 - false_positives_2: 591.4557 - loss: 0.2908
# Epoch 3: val_loss improved from 0.38115 to 0.37305, saving model to AL_Model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.8949 - false_negatives_2: 465.9625 - false_positives_2: 598.4625 - loss: 0.2907 - val_binary_accuracy: 0.8368 - val_false_negatives_2: 538.0000 - val_false_positives_2: 278.0000 - val_loss: 0.3730
# Epoch 4/20
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8988 - false_negatives_2: 482.9481 - false_positives_2: 534.7532 - loss: 0.2690
# Epoch 4: val_loss did not improve from 0.37305
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - binary_accuracy: 0.8988 - false_negatives_2: 500.5375 - false_positives_2: 554.8000 - loss: 0.2691 - val_binary_accuracy: 0.8154 - val_false_negatives_2: 730.0000 - val_false_positives_2: 193.0000 - val_loss: 0.4304
# Epoch 5/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9045 - false_negatives_2: 447.9487 - false_positives_2: 471.7308 - loss: 0.2665
# Epoch 5: val_loss did not improve from 0.37305
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - binary_accuracy: 0.9047 - false_negatives_2: 458.1250 - false_positives_2: 483.1875 - loss: 0.2662 - val_binary_accuracy: 0.8408 - val_false_negatives_2: 416.0000 - val_false_positives_2: 380.0000 - val_loss: 0.3773
# Epoch 6/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9152 - false_negatives_2: 414.9620 - false_positives_2: 463.8354 - loss: 0.2323
# Epoch 6: val_loss did not improve from 0.37305
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.9152 - false_negatives_2: 419.9250 - false_positives_2: 469.4000 - loss: 0.2324 - val_binary_accuracy: 0.8396 - val_false_negatives_2: 450.0000 - val_false_positives_2: 352.0000 - val_loss: 0.3879
# Epoch 7/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9265 - false_negatives_2: 374.5696 - false_positives_2: 394.2785 - loss: 0.2161
# Epoch 7: val_loss did not improve from 0.37305
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.9265 - false_negatives_2: 379.2125 - false_positives_2: 399.2500 - loss: 0.2162 - val_binary_accuracy: 0.8346 - val_false_negatives_2: 302.0000 - val_false_positives_2: 525.0000 - val_loss: 0.4055
# Epoch 7: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 563.0, Number of ones incorrectly classified: 282.0
# Sample ratio for positives: 0.3337278106508876, Sample ratio for negatives:0.6662721893491125
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - binary_accuracy: 0.8766 - false_negatives_3: 675.4286 - false_positives_3: 821.7143 - loss: 0.3360
# Epoch 1: val_loss improved from 0.37305 to 0.36230, saving model to AL_Model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - binary_accuracy: 0.8766 - false_negatives_3: 682.2828 - false_positives_3: 829.1919 - loss: 0.3358 - val_binary_accuracy: 0.8430 - val_false_negatives_3: 261.0000 - val_false_positives_3: 524.0000 - val_loss: 0.3623
# Epoch 2/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8959 - false_negatives_3: 619.4688 - false_positives_3: 692.9375 - loss: 0.2852
# Epoch 2: val_loss did not improve from 0.36230
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - binary_accuracy: 0.8958 - false_negatives_3: 638.5455 - false_positives_3: 714.6869 - loss: 0.2853 - val_binary_accuracy: 0.8470 - val_false_negatives_3: 323.0000 - val_false_positives_3: 442.0000 - val_loss: 0.3630
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9020 - false_negatives_3: 590.1326 - false_positives_3: 666.0102 - loss: 0.2645
# Epoch 3: val_loss did not improve from 0.36230
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - binary_accuracy: 0.9020 - false_negatives_3: 596.0202 - false_positives_3: 672.7677 - loss: 0.2645 - val_binary_accuracy: 0.8162 - val_false_negatives_3: 723.0000 - val_false_positives_3: 196.0000 - val_loss: 0.4252
# Epoch 4/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9041 - false_negatives_3: 565.4271 - false_positives_3: 615.1354 - loss: 0.2528
# Epoch 4: val_loss did not improve from 0.36230
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - binary_accuracy: 0.9042 - false_negatives_3: 582.4041 - false_positives_3: 634.0202 - loss: 0.2529 - val_binary_accuracy: 0.8376 - val_false_negatives_3: 507.0000 - val_false_positives_3: 305.0000 - val_loss: 0.3775
# Epoch 5/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9201 - false_negatives_3: 480.8969 - false_positives_3: 533.3093 - loss: 0.2296
# Epoch 5: val_loss did not improve from 0.36230
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - binary_accuracy: 0.9200 - false_negatives_3: 490.9192 - false_positives_3: 544.4141 - loss: 0.2297 - val_binary_accuracy: 0.8424 - val_false_negatives_3: 272.0000 - val_false_positives_3: 516.0000 - val_loss: 0.3913
# Epoch 5: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 279.0, Number of ones incorrectly classified: 512.0
# Sample ratio for positives: 0.6472819216182049, Sample ratio for negatives:0.3527180783817952
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - binary_accuracy: 0.8799 - false_negatives_4: 839.1102 - false_positives_4: 944.6780 - loss: 0.3220
# Epoch 1: val_loss did not improve from 0.36230
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - binary_accuracy: 0.8799 - false_negatives_4: 845.8992 - false_positives_4: 952.2101 - loss: 0.3219 - val_binary_accuracy: 0.8294 - val_false_negatives_4: 187.0000 - val_false_positives_4: 666.0000 - val_loss: 0.4005
# Epoch 2/20
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9016 - false_negatives_4: 701.8707 - false_positives_4: 819.3190 - loss: 0.2692
# Epoch 2: val_loss improved from 0.36230 to 0.35547, saving model to AL_Model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - binary_accuracy: 0.9014 - false_negatives_4: 721.4958 - false_positives_4: 841.1765 - loss: 0.2695 - val_binary_accuracy: 0.8502 - val_false_negatives_4: 370.0000 - val_false_positives_4: 379.0000 - val_loss: 0.3555
# Epoch 3/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9089 - false_negatives_4: 677.9492 - false_positives_4: 744.7797 - loss: 0.2491
# Epoch 3: val_loss did not improve from 0.35547
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - binary_accuracy: 0.9089 - false_negatives_4: 683.8067 - false_positives_4: 751.4706 - loss: 0.2492 - val_binary_accuracy: 0.8492 - val_false_negatives_4: 251.0000 - val_false_positives_4: 503.0000 - val_loss: 0.3564
# Epoch 4/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9168 - false_negatives_4: 618.6239 - false_positives_4: 685.8290 - loss: 0.2370
# Epoch 4: val_loss did not improve from 0.35547
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - binary_accuracy: 0.9167 - false_negatives_4: 629.5042 - false_positives_4: 697.8488 - loss: 0.2372 - val_binary_accuracy: 0.7886 - val_false_negatives_4: 94.0000 - val_false_positives_4: 963.0000 - val_loss: 0.5679
# Epoch 5/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9205 - false_negatives_4: 590.7373 - false_positives_4: 638.0932 - loss: 0.2287
# Epoch 5: val_loss did not improve from 0.35547
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - binary_accuracy: 0.9204 - false_negatives_4: 595.8655 - false_positives_4: 643.6387 - loss: 0.2288 - val_binary_accuracy: 0.8324 - val_false_negatives_4: 576.0000 - val_false_positives_4: 262.0000 - val_loss: 0.4162
# Epoch 6/20
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9303 - false_negatives_4: 499.2500 - false_positives_4: 566.5862 - loss: 0.2027
# Epoch 6: val_loss did not improve from 0.35547
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - binary_accuracy: 0.9302 - false_negatives_4: 512.7311 - false_positives_4: 582.4538 - loss: 0.2030 - val_binary_accuracy: 0.8160 - val_false_negatives_4: 148.0000 - val_false_positives_4: 772.0000 - val_loss: 0.5049
# Epoch 6: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8497999906539917, 'false_negatives_4': 389.0, 'false_positives_4': 362.0, 'loss': 0.35304415225982666}
# ----------------------------------------------------------------------------------------------------
